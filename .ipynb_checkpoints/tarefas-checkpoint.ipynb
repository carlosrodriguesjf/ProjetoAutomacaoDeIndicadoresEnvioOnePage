# %% [markdown]
# ## Automação do Processo

# %%
# Importando os dados 
# Criar uma tabela para cada loja
# Criar um pasta para cada loja e salvar as planilhas na pasta Backup Arquivos Lojas. O formato do arquivo salvo deve ser por ex: 05_23_Nome da loja.xlsx 
# Calcular os indicadores para cada loja
# Montar a OnePage
# Enviar pora cada reespectivo gerente
# Criar um ranking para as lojas 
# Enviar um e-mail para a diretoria

# %%
#importando as bibliotecas
import pandas as pd

# %%
#importando base de dados lojas
tabela_lojas = pd.read_csv(r'Bases de Dados\Lojas.csv', encoding='ISO-8859-1', sep=';')
tabela_lojas.head()
# Out:
#    ID Loja                         Loja
# 0        1           Iguatemi Esplanada
# 1        2         Shopping Midway Mall
# 2        3               Norte Shopping
# 3        4  Shopping Iguatemi Fortaleza
# 4        5     Shopping União de Osasco

# %%
#importando base de dados Emails
tabela_emails = pd.read_excel('Bases de Dados/Emails.xlsx')
tabela_emails.head()
# Out:
#                                 Loja      Gerente  \
# 0                 Iguatemi Esplanada       Helena
# 1               Shopping Midway Mall        Alice
# 2                     Norte Shopping        Laura
# 3        Shopping Iguatemi Fortaleza      Manuela
# 4           Shopping União de Osasco    Valentina
# 5         Shopping Center Interlagos       Sophia
# 6                     Rio Mar Recife     Isabella
# 7                  Salvador Shopping      Heloisa
# 8         Rio Mar Shopping Fortaleza        Luiza
# 9   Shopping Center Leste Aricanduva        Julia
# 10                 Ribeirão Shopping       Lorena
# 11                  Shopping Morumbi        Livia
# 12         Parque Dom Pedro Shopping  Maria Luiza
# 13               Bourbon Shopping SP      Cecilia
# 14       Palladium Shopping Curitiba         Eloa
# 15         Passei das Águas Shopping       Miguel
# 16        Center Shopping Uberlândia       Arthur
# 17                   Shopping Recife       Heitor
# 18               Shopping Vila Velha     Bernardo
# 19                Shopping SP Market         Davi
# 20                 Shopping Eldorado         Theo
# 21               Shopping Ibirapuera      Lorenzo
# 22      Novo Shopping Ribeirão Preto      Gabriel
# 23                 Iguatemi Campinas        Pedro
# 24                    Shopping Barra     Benjamin
# 25                         Diretoria    Diretoria
#
#                                              E-mail
# 0        carlosrodriguesjfprojects+helena@gmail.com
# 1         carlosrodriguesjfprojects+alice@gmail.com
# 2         carlosrodriguesjfprojects+laura@gmail.com
# 3       carlosrodriguesjfprojects+manuela@gmail.com
# 4     carlosrodriguesjfprojects+valentina@gmail.com
# 5        carlosrodriguesjfprojects+sophia@gmail.com
# 6      carlosrodriguesjfprojects+isabella@gmail.com
# 7       carlosrodriguesjfprojects+heloisa@gmail.com
# 8         carlosrodriguesjfprojects+luiza@gmail.com
# 9         carlosrodriguesjfprojects+julia@gmail.com
# 10       carlosrodriguesjfprojects+lorena@gmail.com
# 11        carlosrodriguesjfprojects+livia@gmail.com
# 12  carlosrodriguesjfprojects+maria_luiza@gmail.com
# 13      carlosrodriguesjfprojects+cecilia@gmail.com
# 14         carlosrodriguesjfprojects+eloa@gmail.com
# 15       carlosrodriguesjfprojects+miguel@gmail.com
# 16       carlosrodriguesjfprojects+arthur@gmail.com
# 17       carlosrodriguesjfprojects+heitor@gmail.com
# 18     carlosrodriguesjfprojects+bernardo@gmail.com
# 19         carlosrodriguesjfprojects+davi@gmail.com
# 20         carlosrodriguesjfprojects+theo@gmail.com
# 21      carlosrodriguesjfprojects+lorenzo@gmail.com
# 22      carlosrodriguesjfprojects+gabriel@gmail.com
# 23        carlosrodriguesjfprojects+pedro@gmail.com
# 24     carlosrodriguesjfprojects+benjamin@gmail.com
# 25    carlosrodriguesjfprojects+diretoria@gmail.com

# %%
#importando base de dados Vendas
tabela_emails = pd.read_excel('Bases de Dados/Emails.xlsx')
tabela_emails.head()
# Out:
#                           Loja    Gerente  \
# 0           Iguatemi Esplanada     Helena
# 1         Shopping Midway Mall      Alice
# 2               Norte Shopping      Laura
# 3  Shopping Iguatemi Fortaleza    Manuela
# 4     Shopping União de Osasco  Valentina
#
#                                           E-mail
# 0     carlosrodriguesjfprojects+helena@gmail.com
# 1      carlosrodriguesjfprojects+alice@gmail.com
# 2      carlosrodriguesjfprojects+laura@gmail.com
# 3    carlosrodriguesjfprojects+manuela@gmail.com
# 4  carlosrodriguesjfprojects+valentina@gmail.com
